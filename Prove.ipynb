# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("serie-storiche-ristoranti.csv", parse_dates=["data"])
df.sort_values(by="data", inplace=True)
df
# Out:
#            data  scontrini  lordototale id_ristorante
# 0    2018-01-01    21884.0     500409.9          R000
# 1    2018-01-01    19961.0     252223.2          R003
# 2    2018-01-01    19541.0     408110.4          R005
# 3    2018-01-01    23173.0     516431.7          R004
# 4    2018-01-01    28101.0     782775.9          R001
# ...         ...        ...          ...           ...
# 8813 2022-04-30        0.0          0.0          R003
# 8815 2022-04-30        0.0          0.0          R005
# 8811 2022-04-30        0.0          0.0          R004
# 8812 2022-04-30        0.0          0.0          R000
# 8816 2022-04-30        0.0          0.0          R001
#
# [8817 rows x 4 columns]

# %%
df.dtypes
# Out:
# data             datetime64[ns]
# scontrini               float64
# lordototale             float64
# id_ristorante            object
# dtype: object

# %%
rist = []
for id, df_id in df.groupby('id_ristorante', as_index=False):
    temp = df_id.reset_index()
    temp.index.name = 'rist_index'
    rist.append(temp)
    
#rist = [df_id.reset_index() for id, df_id in df.groupby('id_ristorante', as_index=False)]

# %%
[print(df['id_ristorante'][0], df.shape) for df in rist]
# Out:
# R000 (1581, 5)
# R001 (1581, 5)
# R002 (912, 5)
# R003 (1581, 5)
# R004 (1581, 5)
# R005 (1581, 5)
# [None, None, None, None, None, None]

# %%
rist[3]
# Out:
#             index       data  scontrini  lordototale id_ristorante
# rist_index
# 0               1 2018-01-01    19961.0   252223.200          R003
# 1               7 2018-01-02        0.0        0.000          R003
# 2              12 2018-01-03        0.0        0.000          R003
# 3              19 2018-01-04        0.0        0.000          R003
# 4              22 2018-01-05        0.0        0.000          R003
# ...           ...        ...        ...          ...           ...
# 1576         8789 2022-04-26      493.0     9907.056          R003
# 1577         8793 2022-04-27      500.0    10384.065          R003
# 1578         8803 2022-04-28      491.0        0.000          R003
# 1579         8809 2022-04-29        0.0        0.000          R003
# 1580         8813 2022-04-30        0.0        0.000          R003
#
# [1581 rows x 5 columns]

# %% [markdown]
# ## Ristorante 0

# %%
N = 0

# %% [markdown]
# ### Data Exploration

# %%
rist[N].head(40)
# Out:
#             index       data  scontrini  lordototale id_ristorante
# rist_index
# 0               0 2018-01-01    21884.0     500409.9          R000
# 1               6 2018-01-02        0.0          0.0          R000
# 2              14 2018-01-03        0.0          0.0          R000
# 3              18 2018-01-04        0.0          0.0          R000
# 4              23 2018-01-05        0.0          0.0          R000
# 5              26 2018-01-06        0.0          0.0          R000
# 6              32 2018-01-07        0.0          0.0          R000
# 7              39 2018-01-08        0.0          0.0          R000
# 8              44 2018-01-09        0.0          0.0          R000
# 9              46 2018-01-10        0.0          0.0          R000
# 10             51 2018-01-11        0.0          0.0          R000
# 11             57 2018-01-12        0.0          0.0          R000
# 12             62 2018-01-13        0.0          0.0          R000
# 13             67 2018-01-14        0.0          0.0          R000
# 14             71 2018-01-15        0.0          0.0          R000
# 15             78 2018-01-16        0.0          0.0          R000
# 16             82 2018-01-17        0.0          0.0          R000
# 17             86 2018-01-18        0.0          0.0          R000
# 18             94 2018-01-19        0.0          0.0          R000
# 19             99 2018-01-20        0.0          0.0          R000
# 20            101 2018-01-21        0.0          0.0          R000
# 21            107 2018-01-22        0.0          0.0          R000
# 22            114 2018-01-23        0.0          0.0          R000
# 23            118 2018-01-24        0.0          0.0          R000
# 24            120 2018-01-25        0.0          0.0          R000
# 25            126 2018-01-26        0.0          0.0          R000
# 26            130 2018-01-27        0.0          0.0          R000
# 27            136 2018-01-28        0.0          0.0          R000
# 28            141 2018-01-29        0.0          0.0          R000
# 29            148 2018-01-30        0.0          0.0          R000
# 30            152 2018-01-31        0.0          0.0          R000
# 31            158 2018-02-01    17490.0     387601.2          R000
# 32            160 2018-02-02        0.0          0.0          R000
# 33            169 2018-02-03        0.0          0.0          R000
# 34            174 2018-02-04        0.0          0.0          R000
# 35            178 2018-02-05        0.0          0.0          R000
# 36            184 2018-02-06        0.0          0.0          R000
# 37            188 2018-02-07        0.0          0.0          R000
# 38            193 2018-02-08        0.0          0.0          R000
# 39            198 2018-02-09        0.0          0.0          R000

# %%
rist[N].tail(40)
# Out:
#             index       data  scontrini  lordototale id_ristorante
# rist_index
# 1541         8577 2022-03-22      440.0    13232.592          R000
# 1542         8585 2022-03-23      469.0    14247.576          R000
# 1543         8590 2022-03-24      391.0    11186.100          R000
# 1544         8595 2022-03-25      612.0    18569.250          R000
# 1545         8605 2022-03-26      795.0    25975.188          R000
# 1546         8608 2022-03-27      705.0    24046.281          R000
# 1547         8616 2022-03-28      378.0    11214.585          R000
# 1548         8624 2022-03-29      366.0    11072.160          R000
# 1549         8626 2022-03-30      389.0    11803.158          R000
# 1550         8635 2022-03-31      456.0    13355.496          R000
# 1551         8637 2022-04-01      600.0    19801.260          R000
# 1552         8646 2022-04-02      789.0    25717.986          R000
# 1553         8650 2022-04-03      644.0    21790.350          R000
# 1554         8656 2022-04-04      360.0    10687.788          R000
# 1555         8661 2022-04-05      429.0    12855.537          R000
# 1556         8669 2022-04-06      463.0    13627.170          R000
# 1557         8673 2022-04-07      445.0    14395.293          R000
# 1558         8684 2022-04-08      543.0    18104.256          R000
# 1559         8689 2022-04-09      775.0    26669.925          R000
# 1560         8692 2022-04-10      709.0    24117.804          R000
# 1561         8699 2022-04-11      416.0    11610.378          R000
# 1562         8708 2022-04-12      425.0    12908.349          R000
# 1563         8714 2022-04-13      598.0    18678.708          R000
# 1564         8719 2022-04-14      667.0    20775.933          R000
# 1565         8726 2022-04-15      642.0    19875.024          R000
# 1566         8729 2022-04-16      763.0    26556.984          R000
# 1567         8738 2022-04-17      251.0     8641.323          R000
# 1568         8744 2022-04-18      513.0    16804.449          R000
# 1569         8747 2022-04-19      479.0    15872.868          R000
# 1570         8753 2022-04-20      458.0    13873.950          R000
# 1571         8761 2022-04-21      478.0    14178.429          R000
# 1572         8764 2022-04-22      558.0    18014.562          R000
# 1573         8773 2022-04-23      759.0    25895.025          R000
# 1574         8776 2022-04-24      751.0    25958.637          R000
# 1575         8783 2022-04-25      596.0    22498.506          R000
# 1576         8790 2022-04-26      388.0    11091.276          R000
# 1577         8795 2022-04-27      395.0    12207.078          R000
# 1578         8799 2022-04-28      491.0    15157.881          R000
# 1579         8810 2022-04-29        0.0        0.000          R000
# 1580         8812 2022-04-30        0.0        0.000          R000

# %% [markdown]
# Mi sembra di capire che per le prime date ci sono le informazioni di scontrini e biglietti sommati per mese. Per gli ultimi giorni abbiamo invece i dati per ogni singolo giorno.

# %% [markdown]
# ### Data Visualization

# %%
plt.rcParams["figure.figsize"] = [12, 5]

# %% [markdown]
# #### Scontrini

# %%
ax = sns.lineplot(x="data", y="scontrini", data=rist[N])

# %% [markdown]
# #### Lordototale

# %%
ax = sns.lineplot(x="data", y="lordototale", data=rist[N])

# %%
ax = sns.lineplot(x="data", y="lordototale", data=rist[N][rist[N]['data'].dt.year > 2019])
